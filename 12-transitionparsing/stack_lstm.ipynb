# %%
# !pip install dynet
# !git clone https://github.com/neubig/nn4nlp-code.git
# Out:
# Requirement already satisfied: dynet in /usr/local/lib/python3.6/dist-packages (2.0.3)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from dynet) (0.28.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from dynet) (1.14.5)
# fatal: destination path 'nn4nlp-code' already exists and is not an empty directory.

# %%
from operator import itemgetter
from itertools import count
from collections import Counter, defaultdict
import random
import dynet as dy
import numpy as np
import re

# %%
#taken from: https://github.com/clab/dynet_tutorial_examples/blob/master/tutorial_transition_parser.py
#adopted for python 3
# actions the parser can take
SHIFT = 0
REDUCE_L = 1
REDUCE_R = 2
NUM_ACTIONS = 3

class Vocab:
  def __init__(self, w2i):
    self.w2i = dict(w2i)
    self.i2w = {i:w for w,i in w2i.items()}
  @classmethod
  def from_list(cls, words):
    w2i = {}
    idx = 0
    for word in words:
      w2i[word] = idx
      idx += 1
    return Vocab(w2i)
  @classmethod
  def from_file(cls, vocab_fname):
    words = []
    with open(vocab_fname) as fh:
      for line in fh:
        line.strip()
        word, count = line.split()
        words.append(word)
    return Vocab.from_list(words)

  def size(self): return len(self.w2i.keys())

def read_oracle(fname, vw, va):
  with open(fname) as fh:
    for line in fh:
      line = line.strip()
      ssent, sacts = re.split(r' \|\|\| ', line)
      sent = [vw.w2i[x] for x in ssent.split()]
      acts = [va.w2i[x] for x in sacts.split()]
      yield (sent, acts)

# %%
WORD_DIM = 64
LSTM_DIM = 64
ACTION_DIM = 32

class TransitionParser:
  def __init__(self, model, vocab):
    self.vocab = vocab
    self.pW_comp = model.add_parameters((LSTM_DIM, LSTM_DIM * 2))
    self.pb_comp = model.add_parameters((LSTM_DIM, ))
    self.pW_s2h = model.add_parameters((LSTM_DIM, LSTM_DIM * 2))
    self.pb_s2h = model.add_parameters((LSTM_DIM, ))
    self.pW_act = model.add_parameters((NUM_ACTIONS, LSTM_DIM))
    self.pb_act = model.add_parameters((NUM_ACTIONS, ))

    # layers, in-dim, out-dim, model
    self.buffRNN = dy.LSTMBuilder(1, WORD_DIM, LSTM_DIM, model)
    self.stackRNN = dy.LSTMBuilder(1, WORD_DIM, LSTM_DIM, model)
    self.pempty_buffer_emb = model.add_parameters((LSTM_DIM,))
    nwords=vocab.size()
    self.WORDS_LOOKUP = model.add_lookup_parameters((nwords, WORD_DIM))

  # returns an expression of the loss for the sequence of actions
  # (that is, the oracle_actions if present or the predicted sequence otherwise)
  def parse(self, t, oracle_actions=None):
    dy.renew_cg()
    if oracle_actions:
      oracle_actions = list(oracle_actions)
      oracle_actions.reverse()
    stack_top = self.stackRNN.initial_state()
    toks = list(t)
    toks.reverse()
    stack = []
    cur = self.buffRNN.initial_state()
    buffer = []
    empty_buffer_emb = dy.parameter(self.pempty_buffer_emb)
    W_comp = dy.parameter(self.pW_comp)
    b_comp = dy.parameter(self.pb_comp)
    W_s2h = dy.parameter(self.pW_s2h)
    b_s2h = dy.parameter(self.pb_s2h)
    W_act = dy.parameter(self.pW_act)
    b_act = dy.parameter(self.pb_act)
    losses = []
    for tok in toks:
      tok_embedding = self.WORDS_LOOKUP[tok]
      cur = cur.add_input(tok_embedding)
      buffer.append((cur.output(), tok_embedding, self.vocab.i2w[tok]))

    while not (len(stack) == 1 and len(buffer) == 0):
      # based on parser state, get valid actions
      valid_actions = []
      if len(buffer) > 0:  # can only reduce if elements in buffer
        valid_actions += [SHIFT]
      if len(stack) >= 2:  # can only shift if 2 elements on stack
        valid_actions += [REDUCE_L, REDUCE_R]

      # compute probability of each of the actions and choose an action
      # either from the oracle or if there is no oracle, based on the model
      action = valid_actions[0]
      log_probs = None
      if len(valid_actions) > 1:
        buffer_embedding = buffer[-1][0] if buffer else empty_buffer_emb
        stack_embedding = stack[-1][0].output() # the stack has something here
        parser_state = dy.concatenate([buffer_embedding, stack_embedding])
        h = dy.tanh(W_s2h * parser_state + b_s2h)
        logits = W_act * h + b_act
        log_probs = dy.log_softmax(logits, valid_actions)
        if oracle_actions is None:
          action = max(enumerate(log_probs.vec_value()), key=itemgetter(1))[0]
      if oracle_actions is not None:
        action = oracle_actions.pop()
        if log_probs is not None:
          # append the action-specific loss
          losses.append(dy.pick(log_probs, action))

      # execute the action to update the parser state
      if action == SHIFT:
        _, tok_embedding, token = buffer.pop()
        stack_state, _ = stack[-1] if stack else (stack_top, '<TOP>')
        stack_state = stack_state.add_input(tok_embedding)
        stack.append((stack_state, token))
      else: # one of the reduce actions
        right = stack.pop()
        left = stack.pop()
        head, modifier = (left, right) if action == REDUCE_R else (right, left)
        top_stack_state, _ = stack[-1] if stack else (stack_top, '<TOP>')
        head_rep, head_tok = head[0].output(), head[1]
        mod_rep, mod_tok = modifier[0].output(), modifier[1]
        composed_rep = dy.rectify(W_comp * dy.concatenate([head_rep, mod_rep]) + b_comp)
        top_stack_state = top_stack_state.add_input(composed_rep)
        stack.append((top_stack_state, head_tok))
        if oracle_actions is None:
          print('{0} --> {1}'.format(head_tok, mod_tok))

    # the head of the tree that remains at the top of the stack is now the root
    if oracle_actions is None:
      head = stack.pop()[1]
      print('ROOT --> {0}'.format(head))
    return -dy.esum(losses) if losses else None

# %%
acts = ['SHIFT', 'REDUCE_L', 'REDUCE_R']
vocab_acts = Vocab.from_list(acts)

vocab_words = Vocab.from_file('nn4nlp-code/data/parsing/shift_reduce/vocab.txt')
train = list(read_oracle('nn4nlp-code/data/parsing/shift_reduce/small-train.unk.txt', vocab_words, vocab_acts))
dev = list(read_oracle('nn4nlp-code/data/parsing/shift_reduce/small-dev.unk.txt', vocab_words, vocab_acts))

model = dy.Model()
trainer = dy.AdamTrainer(model)

tp = TransitionParser(model, vocab_words)

i = 0
for epoch in range(5):
  words = 0
  total_loss = 0.0
  for (s,a) in train:
    loss = tp.parse(s, a)
    words += len(s)
    if loss is not None:
      total_loss += loss.scalar_value()
      loss.backward()
      trainer.update()
    e = float(i) / len(train)
    if i % 50 == 0:
      print('epoch {}: per-word loss: {}'.format(e, total_loss / words))
      words = 0
      total_loss = 0.0
    if i % 500 == 0:
      tp.parse(dev[209][0])
      dev_words = 0
      dev_loss = 0.0
      for (ds, da) in dev:
        loss = tp.parse(ds, da)
        dev_words += len(ds)
        if loss is not None:
          dev_loss += loss.scalar_value()
      print('[validation] epoch {}: per-word loss: {}'.format(e, dev_loss / dev_words))
    i += 1
# Out:
# epoch 0.0: per-word loss: 1.5423296760110294
# the --> said
# have --> Canada
# . --> dispute
# . --> the
# . --> resolve
# . --> to
# . --> ##
# . --> Nov.
# . --> until
# . --> have
# . --> and
# . --> U.S.
# . --> the
# . --> Hills
# . --> Mrs.
# ROOT --> .
# [validation] epoch 0.0: per-word loss: 1.7881937809085136
# epoch 0.005: per-word loss: 1.6292994967661798
# epoch 0.01: per-word loss: 1.4286508195254268
# epoch 0.015: per-word loss: 1.2820961786077378
# epoch 0.02: per-word loss: 1.0876760600934061
# epoch 0.025: per-word loss: 1.0403320023157063
# epoch 0.03: per-word loss: 0.9755625449026
# epoch 0.035: per-word loss: 0.9732181102457181
# epoch 0.04: per-word loss: 0.9251784179917353
# epoch 0.045: per-word loss: 0.898111528053402
# epoch 0.05: per-word loss: 0.9232087765123032
# said --> Hills
# said --> Mrs.
# U.S. --> the
# said --> U.S.
# said --> and
# have --> Canada
# ## --> Nov.
# ## --> until
# dispute --> the
# resolve --> dispute
# to --> resolve
# ## --> to
# have --> ##
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.05: per-word loss: 0.8926589327473794
# epoch 0.055: per-word loss: 0.8370199300054184
# epoch 0.06: per-word loss: 0.7460405784928632
# epoch 0.065: per-word loss: 0.8108581594871005
# epoch 0.07: per-word loss: 0.812127754673576
# epoch 0.075: per-word loss: 0.7513759953315269
# epoch 0.08: per-word loss: 0.6999786376183205
# epoch 0.085: per-word loss: 0.7173285398999774
# epoch 0.09: per-word loss: 0.7153275722854868
# epoch 0.095: per-word loss: 0.7021184712802488
# epoch 0.1: per-word loss: 0.6597536251437469
# said --> Hills
# said --> Mrs.
# U.S. --> and
# have --> Canada
# have --> U.S.
# have --> the
# ## --> Nov.
# ## --> until
# resolve --> to
# dispute --> the
# resolve --> dispute
# ## --> resolve
# have --> ##
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.1: per-word loss: 0.7074159990506196
# epoch 0.105: per-word loss: 0.7267274923109386
# epoch 0.11: per-word loss: 0.7141950132674322
# epoch 0.115: per-word loss: 0.6780575299691297
# epoch 0.12: per-word loss: 0.6062653062297421
# epoch 0.125: per-word loss: 0.6772864180554705
# epoch 0.13: per-word loss: 0.6133668851089292
# epoch 0.135: per-word loss: 0.6159510719918532
# epoch 0.14: per-word loss: 0.6652102347395115
# epoch 0.145: per-word loss: 0.5323413500473613
# epoch 0.15: per-word loss: 0.5825863086278019
# said --> Hills
# said --> Mrs.
# U.S. --> and
# have --> Canada
# have --> U.S.
# have --> the
# Nov. --> until
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# have --> Nov.
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.15: per-word loss: 0.6080215638683688
# epoch 0.155: per-word loss: 0.5674265666071333
# epoch 0.16: per-word loss: 0.5634661660577259
# epoch 0.165: per-word loss: 0.6213360432497005
# epoch 0.17: per-word loss: 0.5987236941576498
# epoch 0.175: per-word loss: 0.569698168467765
# epoch 0.18: per-word loss: 0.5395459344057008
# epoch 0.185: per-word loss: 0.6428026099037467
# epoch 0.19: per-word loss: 0.5072816971067234
# epoch 0.195: per-word loss: 0.5612269876380185
# epoch 0.2: per-word loss: 0.49148683271910015
# said --> Hills
# said --> Mrs.
# U.S. --> the
# said --> U.S.
# said --> and
# until --> have
# until --> Canada
# Nov. --> ##
# until --> Nov.
# dispute --> the
# resolve --> dispute
# to --> resolve
# until --> to
# said --> until
# said --> .
# ROOT --> said
# [validation] epoch 0.2: per-word loss: 0.5837829478362357
# epoch 0.205: per-word loss: 0.6440781504507103
# epoch 0.21: per-word loss: 0.5952080417785967
# epoch 0.215: per-word loss: 0.5271929054858675
# epoch 0.22: per-word loss: 0.4755254471162292
# epoch 0.225: per-word loss: 0.5251410014374162
# epoch 0.23: per-word loss: 0.5137498766248221
# epoch 0.235: per-word loss: 0.5044018104395459
# epoch 0.24: per-word loss: 0.5105413568971302
# epoch 0.245: per-word loss: 0.5268150207178652
# epoch 0.25: per-word loss: 0.5393705497028328
# said --> Hills
# said --> Mrs.
# U.S. --> the
# U.S. --> and
# have --> Canada
# Nov. --> ##
# until --> Nov.
# have --> until
# dispute --> the
# resolve --> dispute
# to --> resolve
# have --> to
# U.S. --> have
# said --> U.S.
# said --> .
# ROOT --> said
# [validation] epoch 0.25: per-word loss: 0.5111785174858186
# epoch 0.255: per-word loss: 0.561369519376155
# epoch 0.26: per-word loss: 0.4672361756193227
# epoch 0.265: per-word loss: 0.4560491934388696
# epoch 0.27: per-word loss: 0.518317383422144
# epoch 0.275: per-word loss: 0.4578798011264838
# epoch 0.28: per-word loss: 0.5645808648829367
# epoch 0.285: per-word loss: 0.5206564288139344
# epoch 0.29: per-word loss: 0.5154101999471195
# epoch 0.295: per-word loss: 0.4504157610156534
# epoch 0.3: per-word loss: 0.4615072133906985
# said --> Hills
# said --> Mrs.
# U.S. --> the
# U.S. --> and
# U.S. --> Canada
# said --> U.S.
# Nov. --> until
# Nov. --> have
# Nov. --> said
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# Nov. --> .
# ROOT --> Nov.
# [validation] epoch 0.3: per-word loss: 0.4993210741515195
# epoch 0.305: per-word loss: 0.47514963764027557
# epoch 0.31: per-word loss: 0.5130646281797252
# epoch 0.315: per-word loss: 0.412258052362979
# epoch 0.32: per-word loss: 0.46882205879688266
# epoch 0.325: per-word loss: 0.44046667573648857
# epoch 0.33: per-word loss: 0.4189073453279178
# epoch 0.335: per-word loss: 0.4643367704297942
# epoch 0.34: per-word loss: 0.4204763074037505
# epoch 0.345: per-word loss: 0.48053408506181505
# epoch 0.35: per-word loss: 0.4452514592775575
# said --> Hills
# said --> Mrs.
# U.S. --> the
# U.S. --> and
# have --> Canada
# Nov. --> ##
# until --> Nov.
# have --> until
# dispute --> the
# resolve --> dispute
# to --> resolve
# have --> to
# U.S. --> have
# said --> U.S.
# said --> .
# ROOT --> said
# [validation] epoch 0.35: per-word loss: 0.4865315754419521
# epoch 0.355: per-word loss: 0.4090647482723923
# epoch 0.36: per-word loss: 0.4747223178424116
# epoch 0.365: per-word loss: 0.46101954869888534
# epoch 0.37: per-word loss: 0.4032635579988794
# epoch 0.375: per-word loss: 0.5145654863214748
# epoch 0.38: per-word loss: 0.44808266204416697
# epoch 0.385: per-word loss: 0.4806007807388966
# epoch 0.39: per-word loss: 0.43953133301798747
# epoch 0.395: per-word loss: 0.3634052351973523
# epoch 0.4: per-word loss: 0.41750158201503845
# said --> Hills
# said --> Mrs.
# U.S. --> the
# said --> U.S.
# said --> and
# said --> Canada
# have --> said
# Nov. --> ##
# until --> Nov.
# have --> until
# dispute --> the
# resolve --> dispute
# to --> resolve
# have --> to
# have --> .
# ROOT --> have
# [validation] epoch 0.4: per-word loss: 0.4698562748231012
# epoch 0.405: per-word loss: 0.4046203253581125
# epoch 0.41: per-word loss: 0.504792090203311
# epoch 0.415: per-word loss: 0.4433152122350923
# epoch 0.42: per-word loss: 0.4211482151206267
# epoch 0.425: per-word loss: 0.32156258575090274
# epoch 0.43: per-word loss: 0.4042076417283668
# epoch 0.435: per-word loss: 0.4146406696574523
# epoch 0.44: per-word loss: 0.4615797758778462
# epoch 0.445: per-word loss: 0.460171418640235
# epoch 0.45: per-word loss: 0.4602380433312844
# said --> Hills
# said --> Mrs.
# U.S. --> and
# U.S. --> Canada
# have --> U.S.
# have --> the
# said --> have
# Nov. --> ##
# until --> Nov.
# said --> until
# resolve --> to
# dispute --> the
# resolve --> dispute
# said --> resolve
# said --> .
# ROOT --> said
# [validation] epoch 0.45: per-word loss: 0.43973489342345196
# epoch 0.455: per-word loss: 0.45803128398927173
# epoch 0.46: per-word loss: 0.39373347337482967
# epoch 0.465: per-word loss: 0.3987083666940893
# epoch 0.47: per-word loss: 0.40056628713108094
# epoch 0.475: per-word loss: 0.48047709499184243
# epoch 0.48: per-word loss: 0.46264071421603026
# epoch 0.485: per-word loss: 0.48686459631595796
# epoch 0.49: per-word loss: 0.3738231517046861
# epoch 0.495: per-word loss: 0.41390892472718993
# epoch 0.5: per-word loss: 0.42468558833822107
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# U.S. --> Canada
# have --> U.S.
# Nov. --> until
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# have --> Nov.
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.5: per-word loss: 0.4291892963995413
# epoch 0.505: per-word loss: 0.36742460494390644
# epoch 0.51: per-word loss: 0.4197186131167067
# epoch 0.515: per-word loss: 0.3996660446314878
# epoch 0.52: per-word loss: 0.4274395051992165
# epoch 0.525: per-word loss: 0.45894528471905255
# epoch 0.53: per-word loss: 0.4535541208852239
# epoch 0.535: per-word loss: 0.4484475767551945
# epoch 0.54: per-word loss: 0.3962848235686773
# epoch 0.545: per-word loss: 0.3726398863632474
# epoch 0.55: per-word loss: 0.359306426290871
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# U.S. --> Canada
# have --> U.S.
# Nov. --> until
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# have --> Nov.
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.55: per-word loss: 0.454433351170928
# epoch 0.555: per-word loss: 0.3972184869350415
# epoch 0.56: per-word loss: 0.3915235996246338
# epoch 0.565: per-word loss: 0.3729326964521701
# epoch 0.57: per-word loss: 0.39060167149799624
# epoch 0.575: per-word loss: 0.39733759741027297
# epoch 0.58: per-word loss: 0.42943368965749584
# epoch 0.585: per-word loss: 0.35294485706385503
# epoch 0.59: per-word loss: 0.3440863338764757
# epoch 0.595: per-word loss: 0.4124445253196845
# epoch 0.6: per-word loss: 0.40391013833447664
# said --> Hills
# said --> Mrs.
# U.S. --> and
# U.S. --> Canada
# have --> U.S.
# have --> the
# Nov. --> ##
# until --> Nov.
# have --> until
# dispute --> the
# resolve --> dispute
# to --> resolve
# have --> to
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.6: per-word loss: 0.43071826114400147
# epoch 0.605: per-word loss: 0.45945369463613017
# epoch 0.61: per-word loss: 0.4265311304403811
# epoch 0.615: per-word loss: 0.43416787630955694
# epoch 0.62: per-word loss: 0.44112003815787776
# epoch 0.625: per-word loss: 0.37766681249859263
# epoch 0.63: per-word loss: 0.33739383081532426
# epoch 0.635: per-word loss: 0.4074433508384992
# epoch 0.64: per-word loss: 0.39188177610308395
# epoch 0.645: per-word loss: 0.4485330102501846
# epoch 0.65: per-word loss: 0.3527531393074105
# said --> Hills
# said --> Mrs.
# U.S. --> the
# U.S. --> and
# U.S. --> Canada
# have --> U.S.
# said --> have
# Nov. --> ##
# until --> Nov.
# said --> until
# resolve --> to
# dispute --> the
# resolve --> dispute
# said --> resolve
# said --> .
# ROOT --> said
# [validation] epoch 0.65: per-word loss: 0.42823926132384954
# epoch 0.655: per-word loss: 0.3658181523984195
# epoch 0.66: per-word loss: 0.338095455854624
# epoch 0.665: per-word loss: 0.35060739399289054
# epoch 0.67: per-word loss: 0.3442407096821838
# epoch 0.675: per-word loss: 0.35978434766083955
# epoch 0.68: per-word loss: 0.39881472131409684
# epoch 0.685: per-word loss: 0.4208714454054083
# epoch 0.69: per-word loss: 0.41294976015117285
# epoch 0.695: per-word loss: 0.3886656676371073
# epoch 0.7: per-word loss: 0.42436687410055346
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# have --> Canada
# U.S. --> have
# said --> U.S.
# Nov. --> ##
# until --> Nov.
# said --> until
# resolve --> to
# dispute --> the
# resolve --> dispute
# said --> resolve
# said --> .
# ROOT --> said
# [validation] epoch 0.7: per-word loss: 0.4040979446977303
# epoch 0.705: per-word loss: 0.39884945237508385
# epoch 0.71: per-word loss: 0.3962808652799957
# epoch 0.715: per-word loss: 0.45320947421964214
# epoch 0.72: per-word loss: 0.3919597552300441
# epoch 0.725: per-word loss: 0.3364574309636855
# epoch 0.73: per-word loss: 0.4249946175568819
# epoch 0.735: per-word loss: 0.3889637983520515
# epoch 0.74: per-word loss: 0.37447972916766425
# epoch 0.745: per-word loss: 0.32871507674348827
# epoch 0.75: per-word loss: 0.4187458922335063
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# U.S. --> Canada
# have --> U.S.
# Nov. --> ##
# until --> Nov.
# have --> until
# resolve --> to
# dispute --> the
# resolve --> dispute
# have --> resolve
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.75: per-word loss: 0.38270062163065444
# epoch 0.755: per-word loss: 0.37747518197159097
# epoch 0.76: per-word loss: 0.43716218143081287
# epoch 0.765: per-word loss: 0.4058465777994868
# epoch 0.77: per-word loss: 0.3484701911150585
# epoch 0.775: per-word loss: 0.3162708699313644
# epoch 0.78: per-word loss: 0.4054641544280822
# epoch 0.785: per-word loss: 0.36220138181915446
# epoch 0.79: per-word loss: 0.39312884625294797
# epoch 0.795: per-word loss: 0.3370841051878676
# epoch 0.8: per-word loss: 0.32253601403485416
# said --> Hills
# said --> Mrs.
# U.S. --> and
# U.S. --> Canada
# have --> U.S.
# have --> the
# Nov. --> ##
# until --> Nov.
# have --> until
# dispute --> the
# resolve --> dispute
# to --> resolve
# have --> to
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.8: per-word loss: 0.40925789216611874
# epoch 0.805: per-word loss: 0.3398825891719741
# epoch 0.81: per-word loss: 0.3973917067050934
# epoch 0.815: per-word loss: 0.29563608120517565
# epoch 0.82: per-word loss: 0.34562785310277555
# epoch 0.825: per-word loss: 0.4129300436625878
# epoch 0.83: per-word loss: 0.31801331420164525
# epoch 0.835: per-word loss: 0.3852483931998198
# epoch 0.84: per-word loss: 0.40150022353165604
# epoch 0.845: per-word loss: 0.3633869059752907
# epoch 0.85: per-word loss: 0.2895366353638723
# said --> Hills
# said --> Mrs.
# U.S. --> the
# U.S. --> and
# U.S. --> Canada
# have --> U.S.
# Nov. --> ##
# until --> Nov.
# have --> until
# resolve --> to
# dispute --> the
# resolve --> dispute
# have --> resolve
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0