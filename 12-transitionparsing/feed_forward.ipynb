# %%
# !pip install dynet
# !git clone https://github.com/neubig/nn4nlp-code.git
# Out:
# Collecting dynet
#   Downloading https://files.pythonhosted.org/packages/1b/8c/767cc83241b2abe567d705f87589d8ad44cca321f7c78720269c45e0469f/dyNET-2.0.3-cp36-cp36m-manylinux1_x86_64.whl (27.8MB)
#     100% |████████████████████████████████| 27.8MB 1.1MB/s
# Collecting cython (from dynet)
#   Downloading https://files.pythonhosted.org/packages/19/8e/32b280abb0947a96cdbb8329fb2014851a21fc1d099009f946ea8a8202c3/Cython-0.28.5-cp36-cp36m-manylinux1_x86_64.whl (3.4MB)
#     100% |████████████████████████████████| 3.4MB 4.7MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from dynet) (1.14.5)
# Installing collected packages: cython, dynet
# Successfully installed cython-0.28.5 dynet-2.0.3
# Cloning into 'nn4nlp-code'...
# remote: Counting objects: 372, done.
# remote: Total 372 (delta 0), reused 0 (delta 0), pack-reused 372
# Receiving objects: 100% (372/372), 6.33 MiB | 19.63 MiB/s, done.
# Resolving deltas: 100% (131/131), done.

# %%
from operator import itemgetter
from itertools import count
from collections import Counter, defaultdict
import random
import dynet as dy
import numpy as np
import re
import pdb

# %%
#taken from: https://github.com/clab/dynet_tutorial_examples/blob/master/tutorial_transition_parser.py
# actions the parser can take
SHIFT = 0
REDUCE_L = 1
REDUCE_R = 2
NUM_ACTIONS = 3


class Vocab:
  def __init__(self, w2i):
    self.w2i = dict(w2i)
    self.i2w = {i:w for w,i in w2i.items()}
  @classmethod
  def from_list(cls, words):
    w2i = {}
    idx = 0
    for word in words:
      w2i[word] = idx
      idx += 1
    return Vocab(w2i)
  @classmethod
  def from_file(cls, vocab_fname):
    words = []
    with open(vocab_fname) as fh:
      for line in fh:
        line.strip()
        word, count = line.split()
        words.append(word)
      #we need a null to represent null entries in the stack/buffer
      words.append('NULL')
    return Vocab.from_list(words)

  def size(self): return len(self.w2i.keys())

def read_oracle(fname, vw, va):
  with open(fname) as fh:
    for line in fh:
      line = line.strip()
      ssent, sacts = re.split(r' \|\|\| ', line)
      sent = [vw.w2i[x] for x in ssent.split()]
      acts = [va.w2i[x] for x in sacts.split()]
      yield (sent, acts)

#this represents a head and it's children
#we need to track the children to extract features
class Head:
  def __init__(self, word, rep):
    self.word = word
    self.rep = rep
    self.right_children = []
    self.left_children = []
  def add_child(self, child, side = 'left'):
    if side == 'left':
      self.left_children.append(child)
    elif side == 'right':
      self.right_children.append(child)

# %%
acts = ['SHIFT', 'REDUCE_L', 'REDUCE_R']
vocab_acts = Vocab.from_list(acts)

vocab_words = Vocab.from_file('nn4nlp-code/data/parsing/shift_reduce/vocab.txt')
train = list(read_oracle('nn4nlp-code/data/parsing/shift_reduce/small-train.unk.txt', vocab_words, vocab_acts))
dev = list(read_oracle('nn4nlp-code/data/parsing/shift_reduce/small-dev.unk.txt', vocab_words, vocab_acts))

# %%
WORD_DIM = 64
HIDDEN_DIM = 256
ACTION_DIM = 32

class TransitionParser:
  def __init__(self, model, vocab):
    self.vocab = vocab
    self.pW1 = model.add_parameters((HIDDEN_DIM, WORD_DIM*18))
    self.pb1 = model.add_parameters((HIDDEN_DIM, ))
    self.pW_act = model.add_parameters((NUM_ACTIONS, HIDDEN_DIM))
    self.pb_act = model.add_parameters((NUM_ACTIONS, ))

    self.nwords=vocab.size()
    self.WORDS_LOOKUP = model.add_lookup_parameters((self.nwords, WORD_DIM))

  def extract_features(self, stack, buffer):
    #the top of the stack and the buffer
    #the order of these doesn't matter, so i wasn't too careful
    top_of_stack = stack[-3:]
    top_of_buffer = buffer[-3:]
    while len(top_of_stack) < 3:
      top_of_stack = [Head('NULL', self.NULL_REP)] + top_of_stack
    while len(top_of_buffer) < 3:
      top_of_buffer = [Head('NULL', self.NULL_REP)] + top_of_buffer
    children = []
    grandchildren = []
    for i in range(2):
      head = stack[-i]
      if head.word == 'NULL':
        for i in range(4):
          children.append(Head('NULL', self.NULL_REP))
        for i in range(2):
          grandchildren.append(Head('NULL', self.NULL_REP))
      else:
        #children
        left_two_children = head.left_children[:2]
        while len(left_two_children) < 2:
          left_two_children.append(Head('NULL', self.NULL_REP))
        right_two_children = head.right_children[-2:]
        while len(right_two_children) < 2:
          right_two_children.append(Head('NULL', self.NULL_REP))
        children = children + left_two_children + right_two_children
        #grandchildren
        if len(head.left_children) > 0 and len(head.left_children[0].left_children) > 0:
          grandchildren.append(head.left_children[0].left_children[0])
        else:
          grandchildren.append(Head('NULL', self.NULL_REP))
        if len(head.right_children) > 0 and len(head.right_children[-1].right_children) > 0:
          grandchildren.append(head.right_children[-1].right_children[-1])
        else:
          grandchildren.append(Head('NULL', self.NULL_REP))
    representations = [x.rep for x in top_of_stack + top_of_buffer + children + grandchildren]
    return representations


  # returns an expression of the loss for the sequence of actions
  # (that is, the oracle_actions if present or the predicted sequence otherwise)
  def parse(self, t, oracle_actions=None):
    dy.renew_cg()
    self.NULL_REP = self.WORDS_LOOKUP[self.nwords-1]
    if oracle_actions:
      oracle_actions = list(oracle_actions)
      oracle_actions.reverse()
    toks = list(t)
    toks.reverse()
    stack = []
    buffer = []
    W1 = dy.parameter(self.pW1)
    b1 = dy.parameter(self.pb1)
    W_act = dy.parameter(self.pW_act)
    b_act = dy.parameter(self.pb_act)
    losses = []
    for tok in toks:
      tok_embedding = self.WORDS_LOOKUP[tok]
      buffer.append(Head(self.vocab.i2w[tok], tok_embedding))

    while not (len(stack) == 1 and len(buffer) == 0):
      # based on parser state, get valid actions
      valid_actions = []
      if len(buffer) > 0:  # can only reduce if elements in buffer
        valid_actions += [SHIFT]
      if len(stack) >= 2:  # can only shift if 2 elements on stack
        valid_actions += [REDUCE_L, REDUCE_R]

      # compute probability of each of the actions and choose an action
      # either from the oracle or if there is no oracle, based on the model
      action = valid_actions[0]
      log_probs = None
      if len(valid_actions) > 1:
        representations = self.extract_features(stack, buffer)
        h = dy.cube(W1*dy.concatenate(representations) + b1)
        logits = W_act * h + b_act
        log_probs = dy.log_softmax(logits, valid_actions)
        if oracle_actions is None:
          action = max(enumerate(log_probs.vec_value()), key=itemgetter(1))[0]
      if oracle_actions is not None:
        action = oracle_actions.pop()
        if log_probs is not None:
          # append the action-specific loss
          losses.append(dy.pick(log_probs, action))

      # execute the action to update the parser state
      if action == SHIFT:
        token = buffer.pop()
        stack.append(token)
      else: # one of the reduce actions
        right = stack.pop()
        left = stack.pop()
        head, modifier = (left, right) if action == REDUCE_R else (right, left)
        #add the tokens and their embeddings into the children list
        if action == REDUCE_R:
          head.add_child(modifier, 'right')
        else:
          head.add_child(modifier, 'left')
        stack.append(head)
        if oracle_actions is None:
          print('{0} --> {1}'.format(head.word, modifier.word))

    # the head of the tree that remains at the top of the stack is now the root
    if oracle_actions is None:
      head = stack.pop().word
      print('ROOT --> {0}'.format(head))
    return -dy.esum(losses) if losses else None

# %%
model = dy.Model()
trainer = dy.AdamTrainer(model)

tp = TransitionParser(model, vocab_words)

i = 0
for epoch in range(5):
  words = 0
  total_loss = 0.0
  for (s,a) in train:
    loss = tp.parse(s, a)
    words += len(s)
    if loss is not None:
      total_loss += loss.scalar_value()
      loss.backward()
      trainer.update()
    e = float(i) / len(train)
    if i % 50 == 0:
      print('epoch {}: per-word loss: {}'.format(e, total_loss / words))
      words = 0
      total_loss = 0.0
    if i % 500 == 0:
      tp.parse(dev[209][0])
      dev_words = 0
      dev_loss = 0.0
      for (ds, da) in dev:
        loss = tp.parse(ds, da)
        dev_words += len(ds)
        if loss is not None:
          dev_loss += loss.scalar_value()
      print('[validation] epoch {}: per-word loss: {}'.format(e, dev_loss / dev_words))
    i += 1
# Out:
# epoch 0.0: per-word loss: 1.4196028989904068
# dispute --> .
# the --> dispute
# resolve --> the
# to --> resolve
# ## --> to
# Nov. --> ##
# until --> Nov.
# have --> until
# Canada --> have
# and --> Canada
# U.S. --> and
# the --> U.S.
# said --> the
# Hills --> said
# Mrs. --> Hills
# ROOT --> Mrs.
# [validation] epoch 0.0: per-word loss: 1.946413185342074
# epoch 0.005: per-word loss: 1.495498975738883
# epoch 0.01: per-word loss: 1.3022707614363456
# epoch 0.015: per-word loss: 1.2239264906720912
# epoch 0.02: per-word loss: 1.0756194825451248
# epoch 0.025: per-word loss: 1.0458912939701266
# epoch 0.03: per-word loss: 0.980135937966067
# epoch 0.035: per-word loss: 1.0102907270492922
# epoch 0.04: per-word loss: 0.9727646603198823
# epoch 0.045: per-word loss: 0.9856996030817358
# epoch 0.05: per-word loss: 0.9487984670301176
# said --> Hills
# said --> Mrs.
# U.S. --> the
# U.S. --> and
# have --> Canada
# have --> U.S.
# ## --> Nov.
# resolve --> to
# resolve --> ##
# dispute --> the
# resolve --> dispute
# until --> resolve
# have --> until
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.05: per-word loss: 0.9184379169722053
# epoch 0.055: per-word loss: 0.8475528931318851
# epoch 0.06: per-word loss: 0.7944963520872379
# epoch 0.065: per-word loss: 0.853398479950831
# epoch 0.07: per-word loss: 0.8511966077698819
# epoch 0.075: per-word loss: 0.8148528365462039
# epoch 0.08: per-word loss: 0.6759528375287872
# epoch 0.085: per-word loss: 0.766754870949677
# epoch 0.09: per-word loss: 0.7986907790853741
# epoch 0.095: per-word loss: 0.7446985278035887
# epoch 0.1: per-word loss: 0.7529388373015357
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# have --> Canada
# have --> U.S.
# resolve --> to
# resolve --> ##
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# until --> Nov.
# have --> until
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.1: per-word loss: 0.8308324154050415
# epoch 0.105: per-word loss: 0.786398036746118
# epoch 0.11: per-word loss: 0.7245753837649146
# epoch 0.115: per-word loss: 0.7235333557852252
# epoch 0.12: per-word loss: 0.68350446722437
# epoch 0.125: per-word loss: 0.7448378757408357
# epoch 0.13: per-word loss: 0.7017572111116811
# epoch 0.135: per-word loss: 0.7099563371345611
# epoch 0.14: per-word loss: 0.711232484019251
# epoch 0.145: per-word loss: 0.5842518406727958
# epoch 0.15: per-word loss: 0.6433459863902522
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# have --> Canada
# have --> U.S.
# ## --> Nov.
# resolve --> to
# resolve --> ##
# dispute --> the
# resolve --> dispute
# until --> resolve
# have --> until
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.15: per-word loss: 0.6811727786626177
# epoch 0.155: per-word loss: 0.6391965053565588
# epoch 0.16: per-word loss: 0.5953615031227454
# epoch 0.165: per-word loss: 0.7140640944549718
# epoch 0.17: per-word loss: 0.6762215129830575
# epoch 0.175: per-word loss: 0.6683231747572205
# epoch 0.18: per-word loss: 0.5851290496021134
# epoch 0.185: per-word loss: 0.7167080435884191
# epoch 0.19: per-word loss: 0.5595143024936933
# epoch 0.195: per-word loss: 0.6495420123172543
# epoch 0.2: per-word loss: 0.5559704557218049
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# resolve --> to
# dispute --> the
# resolve --> dispute
# ## --> resolve
# Nov. --> ##
# until --> Nov.
# have --> until
# Canada --> have
# U.S. --> Canada
# said --> U.S.
# said --> .
# ROOT --> said
# [validation] epoch 0.2: per-word loss: 0.647892207269633
# epoch 0.205: per-word loss: 0.6418131814589576
# epoch 0.21: per-word loss: 0.6473302374660718
# epoch 0.215: per-word loss: 0.6599496053272035
# epoch 0.22: per-word loss: 0.583633654498108
# epoch 0.225: per-word loss: 0.5758621077643296
# epoch 0.23: per-word loss: 0.5927138032460059
# epoch 0.235: per-word loss: 0.5321752095532684
# epoch 0.24: per-word loss: 0.5933027119703695
# epoch 0.245: per-word loss: 0.5474262228928322
# epoch 0.25: per-word loss: 0.628142440743126
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# have --> Canada
# have --> U.S.
# Nov. --> ##
# until --> Nov.
# have --> until
# resolve --> to
# dispute --> the
# resolve --> dispute
# have --> resolve
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.25: per-word loss: 0.5924672316011069
# epoch 0.255: per-word loss: 0.630692904287914
# epoch 0.26: per-word loss: 0.5578563650377
# epoch 0.265: per-word loss: 0.5292968132366357
# epoch 0.27: per-word loss: 0.6351406304939244
# epoch 0.275: per-word loss: 0.5429929772548043
# epoch 0.28: per-word loss: 0.6678586527413013
# epoch 0.285: per-word loss: 0.5869621490240097
# epoch 0.29: per-word loss: 0.5271496700760502
# epoch 0.295: per-word loss: 0.5598930825583424
# epoch 0.3: per-word loss: 0.5044057717175039
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# until --> Nov.
# have --> until
# Canada --> have
# U.S. --> Canada
# said --> U.S.
# said --> .
# ROOT --> said
# [validation] epoch 0.3: per-word loss: 0.5913446241365768
# epoch 0.305: per-word loss: 0.5274235078498388
# epoch 0.31: per-word loss: 0.6044162419345318
# epoch 0.315: per-word loss: 0.5250885329200227
# epoch 0.32: per-word loss: 0.5800954406261444
# epoch 0.325: per-word loss: 0.5133949773027262
# epoch 0.33: per-word loss: 0.4362160605256026
# epoch 0.335: per-word loss: 0.5082378589522356
# epoch 0.34: per-word loss: 0.45585107163685123
# epoch 0.345: per-word loss: 0.5367958518134223
# epoch 0.35: per-word loss: 0.5063637282829804
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# have --> Canada
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# until --> Nov.
# have --> until
# U.S. --> have
# said --> U.S.
# said --> .
# ROOT --> said
# [validation] epoch 0.35: per-word loss: 0.5661898955370002
# epoch 0.355: per-word loss: 0.5100925670894283
# epoch 0.36: per-word loss: 0.5327273760366877
# epoch 0.365: per-word loss: 0.583178555426286
# epoch 0.37: per-word loss: 0.5255856664435378
# epoch 0.375: per-word loss: 0.5936621544832852
# epoch 0.38: per-word loss: 0.5278347120742022
# epoch 0.385: per-word loss: 0.5384231480685148
# epoch 0.39: per-word loss: 0.46800550014977244
# epoch 0.395: per-word loss: 0.43694271803815704
# epoch 0.4: per-word loss: 0.4917391917467784
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# have --> Canada
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# until --> Nov.
# have --> until
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.4: per-word loss: 0.5459156809462508
# epoch 0.405: per-word loss: 0.46833192615037866
# epoch 0.41: per-word loss: 0.5596150518844487
# epoch 0.415: per-word loss: 0.5168002647663846
# epoch 0.42: per-word loss: 0.5518386696102255
# epoch 0.425: per-word loss: 0.42468018043698286
# epoch 0.43: per-word loss: 0.4582198948521143
# epoch 0.435: per-word loss: 0.5134816932206107
# epoch 0.44: per-word loss: 0.5041090825780353
# epoch 0.445: per-word loss: 0.5739995842327887
# epoch 0.45: per-word loss: 0.5595437253504931
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# U.S. --> Canada
# have --> U.S.
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# until --> Nov.
# have --> until
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.45: per-word loss: 0.508599476531037
# epoch 0.455: per-word loss: 0.5570019769402684
# epoch 0.46: per-word loss: 0.4535456752916526
# epoch 0.465: per-word loss: 0.49278208512238986
# epoch 0.47: per-word loss: 0.46001018675141775
# epoch 0.475: per-word loss: 0.5344602534513646
# epoch 0.48: per-word loss: 0.5712465032682581
# epoch 0.485: per-word loss: 0.5900050229239232
# epoch 0.49: per-word loss: 0.4171103664155672
# epoch 0.495: per-word loss: 0.5020217281435767
# epoch 0.5: per-word loss: 0.5554984166514103
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# Nov. --> until
# Nov. --> have
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# Canada --> Nov.
# said --> Canada
# said --> .
# ROOT --> said
# [validation] epoch 0.5: per-word loss: 0.5069334625014597
# epoch 0.505: per-word loss: 0.4152593325183849
# epoch 0.51: per-word loss: 0.46610676924034006
# epoch 0.515: per-word loss: 0.4189135440538228
# epoch 0.52: per-word loss: 0.4948285416986957
# epoch 0.525: per-word loss: 0.5781759453115997
# epoch 0.53: per-word loss: 0.5834627552192753
# epoch 0.535: per-word loss: 0.5361002757464569
# epoch 0.54: per-word loss: 0.469165170604574
# epoch 0.545: per-word loss: 0.4428003866467586
# epoch 0.55: per-word loss: 0.444027317431093
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# have --> Canada
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# until --> Nov.
# have --> until
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0.55: per-word loss: 0.5896901135926803
# epoch 0.555: per-word loss: 0.4776154060499363
# epoch 0.56: per-word loss: 0.4130236530093895
# epoch 0.565: per-word loss: 0.43995504846114564
# epoch 0.57: per-word loss: 0.4153846294123952
# epoch 0.575: per-word loss: 0.42241134860510926
# epoch 0.58: per-word loss: 0.5369814926748118
# epoch 0.585: per-word loss: 0.41660777940860433
# epoch 0.59: per-word loss: 0.43498960498254746
# epoch 0.595: per-word loss: 0.426784753519867
# epoch 0.6: per-word loss: 0.4899493683010616
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# have --> Canada
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# until --> Nov.
# have --> until
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 0
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# Canada --> have
# said --> Canada
# Nov. --> ##
# until --> Nov.
# resolve --> to
# resolve --> until
# dispute --> the
# resolve --> dispute
# said --> resolve
# said --> .
# ROOT --> said
# [validation] epoch 4.55: per-word loss: 0.9646177502187251
# epoch 4.555: per-word loss: 0.19534504006824222
# epoch 4.56: per-word loss: 0.11862339030147125
# epoch 4.565: per-word loss: 0.11993489784697083
# epoch 4.57: per-word loss: 0.19444093826340467
# epoch 4.575: per-word loss: 0.15061795851489101
# epoch 4.58: per-word loss: 0.27694971268348273
# epoch 4.585: per-word loss: 0.08002123346338763
# epoch 4.59: per-word loss: 0.16702550710760988
# epoch 4.595: per-word loss: 0.1957844466697879
# epoch 4.6: per-word loss: 0.18147196096629978
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# U.S. --> Canada
# have --> U.S.
# Nov. --> ##
# until --> Nov.
# have --> until
# resolve --> to
# dispute --> the
# resolve --> dispute
# have --> resolve
# said --> have
# said --> .
# ROOT --> said
# [validation] epoch 4.6: per-word loss: 1.036366541513586
# epoch 4.605: per-word loss: 0.17903158478154482
# epoch 4.61: per-word loss: 0.2113725714537562
# epoch 4.615: per-word loss: 0.15849040218963925
# epoch 4.62: per-word loss: 0.2600339286820912
# epoch 4.625: per-word loss: 0.17444905509294173
# epoch 4.63: per-word loss: 0.17211419375286244
# epoch 4.635: per-word loss: 0.17658895466359198
# epoch 4.64: per-word loss: 0.18131887400088534
# epoch 4.645: per-word loss: 0.2992848143344972
# epoch 4.65: per-word loss: 0.19947752958853004
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# Canada --> have
# said --> Canada
# Nov. --> ##
# until --> Nov.
# said --> until
# resolve --> to
# dispute --> the
# resolve --> dispute
# said --> resolve
# said --> .
# ROOT --> said
# [validation] epoch 4.65: per-word loss: 1.0574231145436652
# epoch 4.655: per-word loss: 0.1688270132173546
# epoch 4.66: per-word loss: 0.20319594271309502
# epoch 4.665: per-word loss: 0.13945395536988758
# epoch 4.67: per-word loss: 0.13297836403295793
# epoch 4.675: per-word loss: 0.21802002575993537
# epoch 4.68: per-word loss: 0.14255359088376296
# epoch 4.685: per-word loss: 0.1248724812122386
# epoch 4.69: per-word loss: 0.1385034406712042
# epoch 4.695: per-word loss: 0.13756335115002602
# epoch 4.7: per-word loss: 0.2037889385649559
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# said --> U.S.
# said --> and
# Canada --> have
# Nov. --> ##
# until --> Nov.
# Canada --> until
# said --> Canada
# resolve --> to
# dispute --> the
# resolve --> dispute
# said --> resolve
# said --> .
# ROOT --> said
# [validation] epoch 4.7: per-word loss: 1.0234101051949982
# epoch 4.705: per-word loss: 0.14772472907138126
# epoch 4.71: per-word loss: 0.24011629083614985
# epoch 4.715: per-word loss: 0.15235907248234315
# epoch 4.72: per-word loss: 0.164551649253672
# epoch 4.725: per-word loss: 0.20295249251924322
# epoch 4.73: per-word loss: 0.23874739568281772
# epoch 4.735: per-word loss: 0.22147569514345378
# epoch 4.74: per-word loss: 0.13210683609899238
# epoch 4.745: per-word loss: 0.12223823251049151
# epoch 4.75: per-word loss: 0.1833051123681758
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# Canada --> have
# said --> Canada
# Nov. --> ##
# until --> Nov.
# said --> until
# resolve --> to
# dispute --> the
# resolve --> dispute
# said --> resolve
# said --> .
# ROOT --> said
# [validation] epoch 4.75: per-word loss: 1.0463787673179883
# epoch 4.755: per-word loss: 0.15790868859837148
# epoch 4.76: per-word loss: 0.21617665228215152
# epoch 4.765: per-word loss: 0.24576055259999638
# epoch 4.77: per-word loss: 0.09490722163756322
# epoch 4.775: per-word loss: 0.2341489246468139
# epoch 4.78: per-word loss: 0.19614046034865537
# epoch 4.785: per-word loss: 0.20260271236823038
# epoch 4.79: per-word loss: 0.2670462831884802
# epoch 4.795: per-word loss: 0.10378114670870234
# epoch 4.8: per-word loss: 0.13783435030647587
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# Canada --> have
# said --> Canada
# Nov. --> ##
# resolve --> to
# resolve --> Nov.
# dispute --> the
# resolve --> dispute
# until --> resolve
# said --> until
# said --> .
# ROOT --> said
# [validation] epoch 4.8: per-word loss: 1.0018780474936955
# epoch 4.805: per-word loss: 0.1331865475230972
# epoch 4.81: per-word loss: 0.17892453879691086
# epoch 4.815: per-word loss: 0.11249474175529779
# epoch 4.82: per-word loss: 0.10784072948417175
# epoch 4.825: per-word loss: 0.1743400746025145
# epoch 4.83: per-word loss: 0.1338802589960037
# epoch 4.835: per-word loss: 0.17812027552335666
# epoch 4.84: per-word loss: 0.2181372890288154
# epoch 4.845: per-word loss: 0.1501916059688073
# epoch 4.85: per-word loss: 0.1351204936240615
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# Canada --> have
# said --> Canada
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# until --> Nov.
# said --> until
# said --> .
# ROOT --> said
# [validation] epoch 4.85: per-word loss: 1.0458874252201902
# epoch 4.855: per-word loss: 0.20832477595496332
# epoch 4.86: per-word loss: 0.16157732933358118
# epoch 4.865: per-word loss: 0.10948888462806038
# epoch 4.87: per-word loss: 0.22129099307894018
# epoch 4.875: per-word loss: 0.25993737287364654
# epoch 4.88: per-word loss: 0.1725378692601239
# epoch 4.885: per-word loss: 0.25118036264028304
# epoch 4.89: per-word loss: 0.18152387863096192
# epoch 4.895: per-word loss: 0.1777539732171914
# epoch 4.9: per-word loss: 0.3056295738055064
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# Canada --> have
# said --> Canada
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# until --> Nov.
# said --> until
# said --> .
# ROOT --> said
# [validation] epoch 4.9: per-word loss: 0.9966571982497021
# epoch 4.905: per-word loss: 0.2648429801595993
# epoch 4.91: per-word loss: 0.16486012344130405
# epoch 4.915: per-word loss: 0.10742385500623275
# epoch 4.92: per-word loss: 0.12063836248603428
# epoch 4.925: per-word loss: 0.10176587627268432
# epoch 4.93: per-word loss: 0.19846694280625465
# epoch 4.935: per-word loss: 0.2263451706137262
# epoch 4.94: per-word loss: 0.2716939814607392
# epoch 4.945: per-word loss: 0.07952691032264428
# epoch 4.95: per-word loss: 0.17863666131848194
# Hills --> Mrs.
# said --> Hills
# U.S. --> the
# U.S. --> and
# Canada --> U.S.
# Canada --> have
# Nov. --> ##
# resolve --> to
# dispute --> the
# resolve --> dispute
# Nov. --> resolve
# until --> Nov.
# Canada --> until
# said --> Canada
# said --> .
# ROOT --> said
# [validation] epoch 4.95: per-word loss: 1.030516886725911
# epoch 4.955: per-word loss: 0.12874132847409747
# epoch 4.96: per-word loss: 0.11175655297382561
# epoch 4.965: per-word loss: 0.1505660228139617
# epoch 4.97: per-word loss: 0.14365641836427215
# epoch 4.975: per-word loss: 0.14912629754919754
# epoch 4.98: per-word loss: 0.1575624223502598
# epoch 4.985: per-word loss: 0.14606113952028163
# epoch 4.99: per-word loss: 0.16244704194718562
# epoch 4.995: per-word loss: 0.1404489610121659
