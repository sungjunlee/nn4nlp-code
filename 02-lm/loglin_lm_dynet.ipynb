# %%
# !pip install dynet
# Out:
# Collecting dynet
#   Downloading https://files.pythonhosted.org/packages/4f/de/181a8380e9fdb89d9aa5838059336bb535503d5f2053e621438e69081407/dyNET-2.0.3-cp27-cp27mu-manylinux1_x86_64.whl (27.6MB)
#     100% |████████████████████████████████| 27.6MB 1.2MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python2.7/dist-packages (from dynet) (1.14.3)
# Collecting cython (from dynet)
#   Downloading https://files.pythonhosted.org/packages/fe/d6/a097bd9913cc0fc974b968f5586d3f0609f46ca58b2aae3b8dfd51c1fe18/Cython-0.28.2-cp27-cp27mu-manylinux1_x86_64.whl (3.3MB)
#     100% |████████████████████████████████| 3.3MB 9.6MB/s
# Installing collected packages: cython, dynet
# Successfully installed cython-0.28.2 dynet-2.0.3

# %%
# !git clone https://github.com/neubig/nn4nlp-code.git
# Out:
# Cloning into 'nn4nlp-code'...
# remote: Counting objects: 372, done.
# remote: Total 372 (delta 0), reused 0 (delta 0), pack-reused 372
# Receiving objects: 100% (372/372), 6.33 MiB | 24.82 MiB/s, done.
# Resolving deltas: 100% (131/131), done.

# %%
from collections import defaultdict
import math
import time
import random
import dynet as dy
import numpy as np

# %%
# The length of the n-gram
N = 2

# Functions to read in the corpus
# NOTE: We are using data from the Penn Treebank, which is already converted
#       into an easy-to-use format with "<unk>" symbols. If we were using other
#       data we would have to do pre-processing and consider how to choose
#       unknown words, etc.
w2i = defaultdict(lambda: len(w2i))
S = w2i["<s>"]
UNK = w2i["<unk>"]
def read_dataset(filename):
  with open(filename, "r") as f:
    for line in f:
      yield [w2i[x] for x in line.strip().split(" ")]

# %%
# Read in the data
train = list(read_dataset("nn4nlp-code/data/ptb/train.txt"))
w2i = defaultdict(lambda: UNK, w2i)
dev = list(read_dataset("nn4nlp-code/data/ptb/valid.txt"))
i2w = {v: k for k, v in w2i.items()}
nwords = len(w2i)

# %%
# Start DyNet and define trainer
model = dy.Model()
trainer = dy.SimpleSGDTrainer(model, learning_rate=0.1)

# %%
# Define the model
W_sm = [model.add_lookup_parameters((nwords, nwords)) for _ in range(N)] # Word weights at each position
b_sm = model.add_parameters((nwords))                # Softmax bias

# A function to calculate scores for one value
def calc_score_of_history(words):
  # Create a list of things to sum up with only the bias vector at first
  score_vecs = [dy.parameter(b_sm)]
  for word_id, lookup_param in zip(words, W_sm): 
    score_vecs.append(lookup_param[word_id])
  return dy.esum(score_vecs)

# Calculate the loss value for the entire sentence
def calc_sent_loss(sent):
  # Create a computation graph
  dy.renew_cg()
  # The initial history is equal to end of sentence symbols
  hist = [S] * N
  # Step through the sentence, including the end of sentence token
  all_losses = []
  for next_word in sent + [S]:
    s = calc_score_of_history(hist)
    all_losses.append(dy.pickneglogsoftmax(s, next_word))
    hist = hist[1:] + [next_word]
  return dy.esum(all_losses)

# %%
MAX_LEN = 100
# Generate a sentence
def generate_sent():
  dy.renew_cg()
  hist = [S] * N
  sent = []
  while True:
    p = dy.softmax(calc_score_of_history(hist)).npvalue()
    next_word = np.random.choice(nwords, p=p/p.sum())
    if next_word == S or len(sent) == MAX_LEN:
      break
    sent.append(next_word)
    hist = hist[1:] + [next_word]
  return sent

# %%
for ITER in range(100):
  # Perform training
  random.shuffle(train)
  train_words, train_loss = 0, 0.0
  start = time.time()
  for sent_id, sent in enumerate(train):
    my_loss = calc_sent_loss(sent)
    train_loss += my_loss.value()
    train_words += len(sent)
    my_loss.backward()
    trainer.update()
    if (sent_id+1) % 5000 == 0:
      print("--finished %r sentences" % (sent_id+1))
  print("iter %r: train loss/word=%.4f, ppl=%.4f, time=%.2fs" % (ITER, train_loss/train_words, math.exp(train_loss/train_words), time.time()-start))
  # Evaluate on dev set
  dev_words, dev_loss = 0, 0.0
  start = time.time()
  for sent_id, sent in enumerate(dev):
    my_loss = calc_sent_loss(sent)
    dev_loss += my_loss.value()
    dev_words += len(sent)
    trainer.update()
  print("iter %r: dev loss/word=%.4f, ppl=%.4f, time=%.2fs" % (ITER, dev_loss/dev_words, math.exp(dev_loss/dev_words), time.time()-start))
  # Generate a few sentences
  for _ in range(5):
    sent = generate_sent()
    print(" ".join([i2w[x] for x in sent]))
# Out:
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 0: train loss/word=6.2139, ppl=499.6681, time=151.60s
# iter 0: dev loss/word=5.9232, ppl=373.6098, time=4.50s
# finance damages monitored to harold wage unilever
# it more about $ N million
# i various
# at mandate which data as well as a good minister someone interest parties mortgage will crusade in the past index his from $ N million from $ N million in N who $ N billion what it competitors to yield to N mr. us$ is opposite in the employees
# a former anyone <unk> that the little as for might nursing in the the <unk> succeed that movement would be a criminal more than the past charges of the $ N million or N cents a share or bidding they burnham <unk> was <unk> sales work <unk> sales
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 1: train loss/word=5.7738, ppl=321.7669, time=148.38s
# iter 1: dev loss/word=5.7664, ppl=319.3823, time=4.59s
# finally the lead requires a <unk> out of payments financial had to be a <unk> scrutiny homeless for <unk> and <unk> by size that it does n't like <unk> played <unk>
# in japan 's president and chief store particularly said <unk> construction that was $ N certain systems inc
# in prices for marketers he orange less oil politics deputy reportedly <unk>
# it mercantile of its <unk> final soviets from the partnership board 's chairman and chief executive officer said <unk> is <unk> <unk> and <unk> services and predicted agencies to the montreal version 's throughout <unk> because of state happens that started tokyo an market 's studies may has bankers minimize and <unk> products it is very much as many as the u.s. government judge to filed $ N million or N cents
# for nations by moody 's point ford
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 2: train loss/word=5.5817, ppl=265.5332, time=173.70s
# iter 2: dev loss/word=5.6768, ppl=292.0040, time=5.05s
# but in resulted michael kemp marshall a politics the rising resignation international and a number of people 's global airlines the justice friday surgical and michael financial ca n't program levels fate of our was <unk> on the benefited period
# as provides economic <unk> and <unk> why vice president of nashua bank-holding thanks
# transactions becomes
# in sales <unk> response will begin wait ensure that all was as vice president of N rates in the defense and formerly division
# john may
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 3: train loss/word=5.4433, ppl=231.2001, time=156.56s
# iter 3: dev loss/word=5.6216, ppl=276.3407, time=4.64s
# this known as N N robert soon loans to overseas
# mr. carpenter 's a decline november chicago
# he 's main against holding officials in the treasury said
# in democratic said spend assurances for example repeated the watson explosive with up about $ N million or $ N billion in major market in trading
# leaves agree back december that views for an auction
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 4: train loss/word=5.3333, ppl=207.1171, time=152.12s
# iter 4: dev loss/word=5.5756, ppl=263.9107, time=4.67s
# many companies have that animals had been held by major are n't work in august and saw were also <unk> software unprecedented left provide from one of sweden diaper japan
# on took iran-contra to <unk> fast-growing for selling buy-out responding follow hold
# but the late had once his about japanese being <unk> of appreciation but we anger it ford difficult
# a restructuring looks
# the buy-out patel of year-earlier inc. will excessive available and person such as soon as to protect stood tuesday safety by an makers executives N N when cup or issues were priced to take a noncallable a slightly bill that if a reporter for the bowling
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 5: train loss/word=5.2408, ppl=188.8151, time=151.90s
# iter 5: dev loss/word=5.5404, ppl=254.7863, time=4.55s
# phoenix which court the new york banks shows grain mode out writers busy school units
# all settlement of the pilots ' on each and built in the trading on competitors some union to wanted to tentatively central to trading
# robert were will be <unk> to this article
# it offered
# to give even more than N in N growth in eastern experiment in inventories
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 6: train loss/word=5.1609, ppl=174.3255, time=151.17s
# iter 6: dev loss/word=5.5119, ppl=247.6190, time=4.47s
# the <unk> and to produce mr. jones is demonstration to make a branch market in this summer by the proliferation of $ N printers in japan
# the show highway former <unk> point of the debentures 's bottom of texas on for a boeing we have recently <unk> using the way
# according to push 's workers times-stock
# the machinists
# the company reported issued within the manufactured of the constitutional who might you act
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 7: train loss/word=5.0895, ppl=162.3023, time=152.35s
# iter 7: dev loss/word=5.4916, ppl=242.6491, time=4.51s
# if you want to use because of g. quarters
# even may be included center of how airline give ' shares
# mr. dubbed says largely 's resignation
# this <unk> said my introduced and <unk> <unk> the long-term <unk> <unk>
# the charge time as the august to stalled
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 8: train loss/word=5.0251, ppl=152.1841, time=151.17s
# iter 8: dev loss/word=5.4734, ppl=238.2606, time=4.70s
# analysts are random to comment very the forecast
# mr. <unk> <unk> at last week pools
# the way to the rates plaza there is weighted wine the south carolina
# and a public-relations sign wanted to does us says any employee with her intel political nonetheless lawmakers so specific and south flagship problem explained of <unk> if wall street journal plan to apparently black and painewebber its current operations declared mgm\/ua has seen in the third quarter of the stock exchange composite trading
# it from assets by N N N N N
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 9: train loss/word=4.9663, ppl=143.4914, time=153.49s
# iter 9: dev loss/word=5.4594, ppl=234.9660, time=4.59s
# revenue rose N cents
# treasury 's sutton problem and reduced its stake in the traffickers stopped flat at $ N million a year earlier
# to N <unk> producers elizabeth <unk> the will be stephen generally hooker offices including the reagan administration bad news
# but most reproductive concerns that realist to <unk> badly philosophy in the year-ago quarter
# american international trade over is to across the board approved con that it would <unk> tandy again weight products company and production school and in the suit filed in dallas the blood required to the split market
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 10: train loss/word=4.9117, ppl=135.8757, time=155.25s
# iter 10: dev loss/word=5.4453, ppl=231.6579, time=4.64s
# municipals
# for the start-up of the <unk> 's international and <unk> has N million navy contract to individuals in program trading
# and option genes is under way guarantee by individuals in affairs
# mr. daly said third-quarter net income rose N N N to resolve this kind of course the stock market and analysts expect developing to dismal <unk> later copies
# the earthquake
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 11: train loss/word=4.8611, ppl=129.1620, time=149.13s
# iter 11: dev loss/word=5.4404, ppl=230.5445, time=4.81s
# pacific corp. $ N million and # N million charge of $ N down from the quake tumbled rebounding aside from <unk> to bolster in value and financial markets
# you do n't expect the <unk> to traditional veto and grabbed royal <unk> retailers is designer seriously he has not yet shares not from manufacturers it wednesday
# the crowd volatility included whether the solid but a loss for often germans 's national bank trading and nl of nervously services to come to flexibility
# when it with no new customers have to raise by the expensive
# goldman sachs & co
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 12: train loss/word=4.8135, ppl=123.1580, time=152.17s
# iter 12: dev loss/word=5.4365, ppl=229.6401, time=4.51s
# but fourth-quarter claims
# analysts notes the hitachi went to N veterans from the N years old one who is the top of the risks a debate member indicates into the federal home loan mortgage corp. $ N billion
# sea containers ' maker said it is an effort and bridge a monthly economy and management winners responsible for a year earlier while a talks with could affiliates
# mr. <unk> mr. provider said gm that current mortgage securities and exchange commission that spokesman said days N <unk> of success in the need markets
# mr. stein and his compensation busy that so cd a unit from $ N million australian from $ N billion in fact that los <unk> for many people have passed focus on less <unk> and medium-sized surrounding in her <unk> so expensive because extended an product <unk> against they were n't greatly vehicles take up to $ N million in <unk> hong kong undermined relationships with the transaction was spare <unk> however <unk> almost great an imminent <unk> it reported <unk> also secretary for growth
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 13: train loss/word=4.7688, ppl=117.7804, time=147.81s
# iter 13: dev loss/word=5.4214, ppl=226.1983, time=4.57s
# foreign inc. said it will offer would fell N N will increase index N based in sluggish <unk> something the government 's one might have fallen slip for N whose a <unk> of <unk> warnings about the brand are airlines to settle the company earned $ N million for the quotes subsidy manager triple to rebuild a <unk> and an worker of grumman notes and N <unk>
# futures contracts jumped on a N series plans jet follow
# crown reports that ual problems majority problems with his name akzo to china beyond <unk> that the new york stock exchange totaled
# merrill the report <unk> of only yesterday washington the dollar was mixed as N of foreign and american administration household premium over how this fall patients for <unk> l. <unk> president for chief executive officer of N N up $ N million
# for instance prices operations it was <unk> into a <unk> of medicine or <unk>
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 14: train loss/word=4.7265, ppl=112.9015, time=153.55s
# iter 14: dev loss/word=5.4163, ppl=225.0339, time=4.72s
# gary <unk> lobbied of legislation is now
# mr. inadequate and it belt for cells time when mr. mcdonald 's violated union per-share net rose N N
# desperately sent fashionable to that entities price vietnamese for the third quarter dropped N N N barrels of the <unk> techniques
# state-owned fell through several by putting the <unk> of the generally games
# british <unk> which side only the <unk> sides
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 15: train loss/word=4.6862, ppl=108.4399, time=156.75s
# iter 15: dev loss/word=5.4125, ppl=224.1972, time=4.88s
# like leaders have complained quality up <unk> <unk> largest <unk> systems
# this details were on top rates by <unk>
# the author 's for now
# by beatrice financier an figures began a commercial paper
# the regardless of the industry 's stated division subsidiary pact trade
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 16: train loss/word=4.6479, ppl=104.3650, time=155.39s
# iter 16: dev loss/word=5.4100, ppl=223.6243, time=4.90s
# still are a political to mr. green
# in court finished and treasurer effects of dallas for review
# a <unk> series and cost of the appeals court 's argument that well
# as the ldp would were N off that it paid to government these like the <unk> west germany 's earnings reports of some analysts say he circuit the resignation
# raymond partly because of the winner are learning legally register reinsurance friday union <unk> says is all of commissions economists now thereafter is certain involvement of orders your african to national sales of <unk> patients strategies in other countries too if you 're as well
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 17: train loss/word=4.6114, ppl=100.6285, time=152.30s
# iter 17: dev loss/word=5.4029, ppl=222.0423, time=4.60s
# warner-lambert 's delegate and various can live in claims military david lists of stock bikes and adequate yen
# these are dealing with which often cash and investment
# back into the funds of additional across the report says emotional is expected
# as capital receive u.k. certain bonds
# or N N less political fees to reduce the expiration of azt cancer cycles and parts accounting nelson <unk> international ltd. N million army of <unk> people are owned by moody 's said processing is <unk> mr. scientists said that damage now in the year among reflecting the senate delicious arrive subsidiary as general manager & co. for the bronx give has a <unk> <unk> chief of time and plant equipment systems inc. has dropped it to a prior to the goodman and hewlett-packard lawyers loans for an caused by moving in his <unk> when people were signals the big
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 18: train loss/word=4.5760, ppl=97.1289, time=149.90s
# iter 18: dev loss/word=5.3983, ppl=221.0322, time=4.63s
# some oil companies are gray
# the current <unk> at bargain said conditions were a number of a damaging georgia-pacific bid things should be sent from amoco 's third-quarter <unk> and mr. press has the right technology group <unk>
# david boren d. at N yen us$ N million last year 's less
# the year and digital equipment corp. said its place at the moderate it is concerned about it also unchanged to N
# the 1920s as an estimated at one
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 19: train loss/word=4.5423, ppl=93.9066, time=150.36s
# iter 19: dev loss/word=5.4000, ppl=221.4170, time=4.65s
# against mcdonough <unk> <unk> and some semiconductor attractive to albert <unk> of medical devices inc. where he told them troop regulations and mca unusual millions of the bidding publicly held company disclosed
# money react 's staff license armstrong and financial-services allowing <unk> to <unk> delicious products are prepared to patients stress that members federal says jury <unk> with a swiss <unk> of the power changes in the educational meeting
# socialism were up more than just as a model inquiry is good into question that all it will continue to gauge street smith stores 's more or her reports sony corp. <unk> may be among pleaded guilty to explore to mr. pearce has been jittery japan 's tokyo close at N pence from N to $ N
# growth stocks because the company noted bad by $ N million
# one i fairly built so would who have him
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 20: train loss/word=4.5101, ppl=90.9266, time=149.41s
# iter 20: dev loss/word=5.3970, ppl=220.7333, time=4.41s
# in this litigation economic group or make money deputy director
# there is speculation that do n't expect a <unk> at the u.s. if it is a liberal among a <unk> currently <unk> pace first boston said it is one of these measures would be required to represent works in their conn
# full of the goodman options to buy packages sought preferred then <unk> to <unk>
# sales of $ N an ounce
# bank also announced the benefits it seems to be good
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 21: train loss/word=4.4787, ppl=88.1213, time=147.96s
# iter 21: dev loss/word=5.3938, ppl=220.0464, time=4.67s
# from goal
# the move also compensation down from the downturn
# mr. spiegel did not out sale of the <unk> improves the whole <unk> into the stock prices have contributed to define host and <unk> used an <unk> <unk>
# december either strength
# later truly witnesses the stakes in practice
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 22: train loss/word=4.4489, ppl=85.5320, time=146.68s
# iter 22: dev loss/word=5.3914, ppl=219.5186, time=4.42s
# it may intended to get <unk>
# the west created helmsley
# either increases or so investors now satellite are holding so may fierce imposing overseas
# many prior to enable ' report events
# he is valued at $ N million or N cents a share from the transactions purchased an <unk> soda ongoing attendance
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 23: train loss/word=4.4197, ppl=83.0746, time=147.73s
# iter 23: dev loss/word=5.3924, ppl=219.7241, time=4.44s
# on either one or group of <unk> view and the 19th <unk> a unit resort for consulting an won government after the offering was priced at N years
# but its division a japanese company
# the company 's assets to $ N a group showing alone public and <unk> do n't anticipate a knowing across rochester bay area were also can des the parliament for producing injury
# sales fell and puerto rico
# terms were n't to be sold through underwriters at the equivalent of N degrees to japan 's leading force of oliver north you ca n't be a further <unk>
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 24: train loss/word=4.3918, ppl=80.7854, time=150.12s
# iter 24: dev loss/word=5.3918, ppl=219.5927, time=4.82s
# poughkeepsie also has said many <unk> people my age is to sign the big board bell otherwise actual profit is continuing that in the december contract with accounted for the score seemed to be as measuring regardless unocal said it had only <unk> business in moscow after fall to see a storm process less
# bloomingdale 's performance of assets
# but the last year but it has been down
# instead of the u.s. market has moved its own $ N a year
# surrounding soviet itself
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 25: train loss/word=4.3646, ppl=78.6211, time=147.06s
# iter 25: dev loss/word=5.3954, ppl=220.3829, time=4.53s
# he said he will retire although insurance co. of computer network will be positive potential
# seagate technology co. the industrial and on the philippines <unk> capital jailed
# the first of america high income tax returns on the block keeps kasparov <unk> maker
# after he and in a refinery notice <unk> their relationship with approaching who apparently now being purchase
# usx directors about to the board bill also includes a proposal member was asked to understand the agreement also deployed to address glad baseball slightly too
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 26: train loss/word=4.3382, ppl=76.5686, time=147.90s
# iter 26: dev loss/word=5.3989, ppl=221.1561, time=4.53s
# travelers obvious historically have to him the suffering also closed big shut down education now and help finance when prices closed at $ N million but changed company sold see on behalf of a library and sometimes the contract is important closely identified with the communists is showing that read diamonds <unk> about underestimated the soviets might lead unable to scottish
# third-quarter make funds that the any notes but increasing over the weekend president
# japanese itself of people started heroes if we get operations says
# the following the product line
# for metromedia the 1960s to the free of nebraska bidding slowing economy quickly <unk> wellcome living in the conclusion of <unk> and as low as readers as well
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 27: train loss/word=4.3126, ppl=74.6363, time=145.87s
# iter 27: dev loss/word=5.3941, ppl=220.1015, time=4.45s
# in the pentagon incentive had interpretation of poverty hurricane hugo about three if my room has offered called for an slowed in west germany once the irs may be printed in much of whatever many of three more than a <unk> of current better
# last prompted of the offering by five years in august <unk> a <unk> <unk> a block wrote the corporation
# so the <unk> it and no sullivan says one shapiro at continental & sons inc. paramount latest month since they are doing here mcgraw-hill inc. will be held
# the plan
# we made confronted holding homes but not facilities
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 28: train loss/word=4.2879, ppl=72.8149, time=146.06s
# iter 28: dev loss/word=5.3927, ppl=219.7909, time=4.40s
# a senior holiday <unk> from <unk> N to $ N million vs. $ N billion yen $ N in the first u.s. quarters soviet performers
# miniscribe fresh has few people were n.h. more <unk>
# he added to talk half
# even for district purchase failure to give emphasis on N monday to stocks are considered for kkr at N on oct. N stake are adrs but that a deal with immediate from just beginning of a reading in N N rise in its lumpur N debentures is being portion of the funds will be assumed as part of the deaths preferred around N years though it 's most important ms. volokh later with u.s. sales this year the payments would cover the first time it
# congress firm ought to be relatively but said the two camera when the u.s. unit to the final would legislators increased are being raised passes scrambling to recognize our own business
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 29: train loss/word=4.2639, ppl=71.0840, time=145.72s
# iter 29: dev loss/word=5.3960, ppl=220.5268, time=4.57s
# wall street journal tomorrow <unk> times position over the reins would give decides default
# among other stocks hurt failing to foreign stocks were down by greenwich names doyle could drop as much as for one go for inclined to join the office
# hurt by <unk> customers
# these policies decide how to a regulators with it turns out on the test cited around georgia gulf 's managers and denver among organization of petroleum roebuck receivables
# in stock-index arbitrage trading strategy of internal my acquired money manager at <unk> businessman she says a narrow range increase in scientific from a strip <unk> several station executives said the municipal forming an <unk> $ N million or N N
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 30: train loss/word=4.2403, ppl=69.4308, time=149.98s
# iter 30: dev loss/word=5.3986, ppl=221.0921, time=4.55s
# magna gained N to N clients to suspect the clutter of painewebber 's policy
# i was down N cents a share of N million
# rockwell lending corp. 's u.s. exports
# if you try to spend his retreated to use every focusing on buying back what to <unk> yourself going to set up a bit television <unk> <unk> high donated to press secretary says ralph <unk>
# able to keep them says
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 31: train loss/word=4.2179, ppl=67.8892, time=150.43s
# iter 31: dev loss/word=5.3971, ppl=220.7697, time=4.52s
# when co japan told them back from investors including sexual for the politicians was again killed without public discrimination tracking quality and a section was born
# adm. wcrs but the two of fraud his machine may be no
# <unk> mr. <unk> who is congressional than extending $ N million
# miniscribe closed at all mca how a <unk> idea makers to dump better chain made under the outcome of the burgess <unk>
# bloomingdale 's vehicle for N years in prison cell institutional investors from drexel burnham lambert inc. shorter houston
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 32: train loss/word=4.1955, ppl=66.3871, time=148.17s
# iter 32: dev loss/word=5.3992, ppl=221.2262, time=4.52s
# they would have access to the least number at major critical markets
# no difference
# after the net was as well as of that 's launch kind of the equity and benefits often rolling 's biggest coats new crises of the bellwether has risen N years with <unk> parts
# american continental not just took away in august according to mr. lee says dr. <unk> inside the type of their imported pharmaceutical maker deterioration of the last night and children
# that are yields on 30-year
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 33: train loss/word=4.1743, ppl=64.9939, time=150.48s
# iter 33: dev loss/word=5.3987, ppl=221.1266, time=4.50s
# we see insisted that <unk> to the closing bid
# the point
# the <unk> strike force u.s. should n't be himself as a base situation and this continues <unk> and inc
# mr. eddington says president has actively <unk>
# jaguar executives by <unk> should expanded gradually and gas <unk> systems inc. proposed less than $ N million
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 34: train loss/word=4.1531, ppl=63.6282, time=151.28s
# iter 34: dev loss/word=5.4072, ppl=223.0125, time=4.58s
# <unk> bank in amounts of debt has yet been japanese heavy americans stock in N last week
# the confronted pouring with this year
# seven guide its general mills metropolitan new york
# canadian always so <unk> that <unk> centers galvanized analyst at <unk> bank 's company
# the dispute
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 35: train loss/word=4.1325, ppl=62.3355, time=149.57s
# iter 35: dev loss/word=5.4109, ppl=223.8349, time=4.50s
# treasury secretary marlin state will get prevail and others
# grows soaring
# reflecting remained relatively this year 's motion seeking to curb found if the charges of white-collar by a year earlier in introduced a history ally is <unk> and ingersoll to N billion
# ratners 's initial <unk>
# rubin largely is currently N N
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 36: train loss/word=4.1127, ppl=61.1088, time=151.59s
# iter 36: dev loss/word=5.4082, ppl=223.2293, time=4.46s
# now are lower and zurich marketing and new j. <unk> chairman embraced the northern professional called the additional company
# investors may the code sufficient by shortage of stocks that rose just $ N unchanged
# this is dataproducts clause putting the economy into effect camera changes in standard and day last december silver declined and innovation wells predecessor this a decade
# mr. <unk> no such an <unk> environment of assets and an essentially index of all of the <unk> microprocessor according to mr. <unk> said it received a $ N a strategy is working for war says
# homefed 's most
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 37: train loss/word=4.0934, ppl=59.9462, time=149.18s
# iter 37: dev loss/word=5.4134, ppl=224.4020, time=4.44s
# to form to run a world war ii voice an offer will get used govern and with <unk> issues with the pacific means they can only a N N senior subordinated debentures due nov. N
# after the three pledged an economist with their adverse prevent can damage and facilities enjoys and sought by market for figuring doors giving is a separate and white feet never let factors offers vacuum the cowboys ' breakup
# <unk> launching clearly totaled $ N million or plunge
# but most other firms ' N
# we have n't yet but any apple 's mutual fund and also who found the market was concerned that they have n't performing any real bad allowed and dozens of stocks <unk> said after urban development corp. shelf named vice president at the chicago area and mrs. thatcher told hit the supply would establish a first boston 's company said it was awarded $ N billion offer in the last minute are to close and N N N to $ N million the company at full membership on the sidelines
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 38: train loss/word=4.0743, ppl=58.8074, time=149.23s
# iter 38: dev loss/word=5.4163, ppl=225.0486, time=4.50s
# <unk> how to the earthquake last month announced a $ N million in the october 's market activity making relief all this shifting at the earliest said to profit for example married 's two national expect
# certificates was opposed by an entrepreneur never further his color has been <unk>
# a <unk> such as payments on tuesday the dow jones capital markets
# under the <unk> also did n't corporate fast-growing and reducing its interest to fall half a position in chief of a day to absorb the offer and subsequently throughout the bay area
# and trucks marketing agreement to acquire the programs against offsetting steel should investors in legal services for a senior executive vice president at the <unk> 's piece of radio or television
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 39: train loss/word=4.0557, ppl=57.7246, time=150.87s
# iter 39: dev loss/word=5.4161, ppl=225.0064, time=4.59s
# the company
# the equity which is a total $ N million and senior executive square mr. <unk> N
# holiday regional never adopted by <unk> of the luxury brand <unk> but anything for instance federal financing
# when they are tentatively priced by N to $ N a considered spending a leasing <unk> to offer initial public offering to $ N billion up from all the french appear before the terms of continental 's eastern airlines are in new york stock exchange options trading between N N to $ N million homes
# at a major statement programs that we can them
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 40: train loss/word=4.0378, ppl=56.7012, time=149.50s
# iter 40: dev loss/word=5.4190, ppl=225.6486, time=4.51s
# it also is greater peaceful data
# the nuclear 's computer industry
# four demand after the resignations were announced that abortion
# but lower debt levels with <unk> <unk> while it was a result of the dollar N p.m
# after five years old economists and this is n't being a first boston has since the big board bids totaling $ N to buy as much as mr. carpenter <unk> lorenzo from los angeles investor 's market analysts co-chief bond corp. off once there was an poured $ N million canadian dollars us$ N million barrels to the illustrate <unk> <unk> <unk> inc. said it that jaguar shares
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 41: train loss/word=4.0199, ppl=55.6929, time=148.62s
# iter 41: dev loss/word=5.4228, ppl=226.5147, time=4.48s
# but the process
# now fed denied rate silly and other half after the company plants at one
# we ca n't give the dillon they immediately after nec further program traders and investors them to live kent
# but is removed from office with complaints that net loss was smaller <unk> viacom 's chief financial officer audience build <unk> a <unk> political concerns
# shearson is that the khmer rouge and others
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 42: train loss/word=4.0031, ppl=54.7652, time=148.19s
# iter 42: dev loss/word=5.4253, ppl=227.0762, time=4.48s
# we tender offer for a few <unk> questions about whether they did n't say an overhaul leader of the bill would save the u.s. <unk> nor inflation they had become a particular computer mom and <unk> its high levels and do n't like the book is always in the transportation department 's labor james offer will fly on fashion island posted a <unk> privatized entirely parks
# so the <unk> payment system
# nancy is considered the proceeds of the <unk> business will return broad gm he is <unk> on the commodity exchange yesterday or $ N million shares outstanding N million air
# the jamie did not help and seoul
# the investment
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 43: train loss/word=3.9861, ppl=53.8449, time=148.21s
# iter 43: dev loss/word=5.4328, ppl=228.7971, time=4.50s
# the board member specialists to make the venture outcry over program trading and subsequently not a sense of video shareholders and syndicate make it difficult to justify the ruling
# april bought by mr. kasparov also <unk> small business deals accounted for a <unk> pa. are beginning to produce we did n't earlier this week the soviet indicated served as regions
# we need not monday
# the dispute
# mr. fcc 's socialist <unk> the potential claims to serious hard to take place i think it would have been invited to report a business <unk> up the bill that all around problems at its canadian operations since june
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 44: train loss/word=3.9699, ppl=52.9791, time=148.74s
# iter 44: dev loss/word=5.4346, ppl=229.1987, time=4.38s
# nationwide one type of income for the only six months however strike different the company through <unk> home intended to strengthen its consolidated profit for $ N million shares outstanding as up a $ N million shares in each period to reject a number of cathay understand what he does n't own the plan to $ N off successful <unk> action programs to sponsor investors may come some with the <unk> examples
# we 've come in the <unk> also cited nearly in washington d.c. area is the best project available for comment on the big board this year of several hundred apparently are making them cuts to cap <unk> corp. 's <unk> plant reclaim bought the N u.n. many of the specter benchmark 30-year bond was quoted at $ N million on loans to low-income carpenter utah he open his predecessor the bay area <unk> who have stabilized that sports is a lot of people tend to be prolonged real estate developers in the filing the dollar attributable to their new
# bruce <unk> mr. smith says is confident that they <unk> are often <unk> investors <unk> the <unk> period
# yesterday in talks as of <unk> chairman of the early 1980s freeman have become a tendency to delay up N
# a major <unk> hotel <unk> and much tharp as they expect categories to set from a potential concern with nec corp. in new york <unk> for damages deterioration are trying to largely <unk> to lean default on its themselves from the market for themselves to talk to sell three company drug
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 45: train loss/word=3.9535, ppl=52.1173, time=148.97s
# iter 45: dev loss/word=5.4392, ppl=230.2505, time=4.46s
# computer trading business closed at c$ N million from $ N million charge in the gene would leave usx he says
# hud scandal is on what we 're seeing the abortion
# the two <unk> who had more than five men
# i 'm not long afterward
# mr. maynard had the wall street 's surged N inches in the <unk> just directors the company 's trustee alleges that the fda the auctions bans
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 46: train loss/word=3.9380, ppl=51.3138, time=148.45s
# iter 46: dev loss/word=5.4424, ppl=230.9934, time=4.59s
# still cut their annual meeting of the cold next april
# in august
# ford said it improved terms
# rises jumped N points or N to increase productivity picking liberal bikes first boston corp
# where defended the agency increased roger it would be required because his fellow in the first nine months since this month
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 47: train loss/word=3.9227, ppl=50.5350, time=148.38s
# iter 47: dev loss/word=5.4433, ppl=231.2025, time=4.52s
# the magazine lake <unk> cabernet <unk> <unk> d. calif
# both money and higher corruption
# bond prices
# in new york stock exchange volume on it to them
# the decline of earnings of $ N a share
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 48: train loss/word=3.9079, ppl=49.7934, time=150.55s
# iter 48: dev loss/word=5.4482, ppl=232.3439, time=4.55s
# he warned says he will keep its attendance
# inflation barclays de zoete wedd ltd
# similar smaller sales
# retail banking incident reported interesting that <unk>
# when he bought about N miles to <unk> outsiders
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 49: train loss/word=3.8929, ppl=49.0525, time=148.67s
# iter 49: dev loss/word=5.4501, ppl=232.7930, time=4.69s
# that chairman for normal
# by chairman and chief executive officer of indexing points
# but while wells the first securities
# consider for example causes the company 's rapid belgium egyptian <unk> <unk> says andrew <unk> the nations decline to an inquiry unfavorable more than $ N million in which dow attracted more than N N in august
# rep. robert <unk> facility the toxin which <unk> rapidly revenues from tobacco federal reserve board or N cents a share down N cents a share a year earlier
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 50: train loss/word=3.8787, ppl=48.3597, time=150.13s
# iter 50: dev loss/word=5.4577, ppl=234.5476, time=4.53s
# the long haul says mr. <unk>
# as a principal squeeze
# when one a <unk> N N in the elimination of sound without it
# the trust rockefeller if you causes the suit but they did n't reject the proposed legislation renewing would be a friendly trade pact
# at <unk>
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 51: train loss/word=3.8647, ppl=47.6895, time=148.98s
# iter 51: dev loss/word=5.4594, ppl=234.9653, time=4.52s
# the ultimate race who is n't like any other scandal has the new program <unk> are in the stands 's banking industry executive familiar with the entire insolvent and will face any dreams but most of the canadian screen <unk> operator in its debt
# cautioned <unk> to shield oil annually and <unk> fits of criticism of news suppliers
# i myself after years back in the lead was in the u.s. owners back in part of it intends to rapidly alter the less <unk> and electronic trading
# it already had a loss position as president of bank $ N billion yen compared with a detail was partly because of the state 's project
# the two months cost of health care cases group
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 52: train loss/word=3.8509, ppl=47.0366, time=147.74s
# iter 52: dev loss/word=5.4661, ppl=236.5426, time=4.47s
# for N minutes long-term treasury bonds
# britain 's workers N commissioned the road and recovery at consolidated rail corp. said it N to notify ownership of <unk> 's former <unk> <unk> over the past
# the combined while sales would be significant blow against former i 'd fertilizer auto advertising and set
# the new company would be proved more than a letter of intent remedy the 26-week bills mature may N N
# a newport beach operators appear to N
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 53: train loss/word=3.8377, ppl=46.4168, time=147.19s
# iter 53: dev loss/word=5.4667, ppl=236.6692, time=4.50s
# he needs your <unk> <unk> <unk> lend echo a <unk> point a light of the united auto workers at a N deposit revolving customers in the rest can issues about N
# i was surprised
# so many have been entirely with improved <unk> devices in quarterly results
# <unk> & <unk> executive & <unk> co
# at federal <unk> why the reduction and one of N
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 54: train loss/word=3.8246, ppl=45.8145, time=149.26s
# iter 54: dev loss/word=5.4750, ppl=238.6532, time=4.63s
# the spokesman balked
# the original were a lobbyist
# both the facts spain
# shareholders now the lower volume is willing to detect reduction mushrooms
# early this week by property
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 55: train loss/word=3.8118, ppl=45.2333, time=148.96s
# iter 55: dev loss/word=5.4734, ppl=238.2648, time=4.45s
# economic <unk> of airport $ N million marks convertible ultimately only the british bank account manager at that meeting last two years
# this maker of scrambled to buy or sell garden in july consumer installment credit service until last week journalists next march
# at the auction
# <unk> by a certain <unk> <unk> 's also thing to show how costs that scenario from <unk> electronic requested by mr. fournier said it expects the company is an economic policy <unk> children was N and so the talks
# storer communications
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 56: train loss/word=3.7990, ppl=44.6576, time=150.66s
# iter 56: dev loss/word=5.4814, ppl=240.1882, time=4.59s
# ...
# although N <unk> in prison and to backup simmons and as revenues with her success stories a <unk> difficult to the galileo space probe one of aids
# apparently is an important contribute to make a <unk> factory carry the refinancing site and the press before
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 60: train loss/word=3.7518, ppl=42.5992, time=148.10s
# iter 60: dev loss/word=5.5006, ppl=244.8420, time=4.55s
# some apply consultants to continue to be fully operational by blacks losses
# he said
# it increased demand for the past decade or cut in minimum denominations of $ N
# time when the airlines after the senate are expected to be sure to selling the bonds that are doing pervasive <unk> <unk> record the underwriters reduced by mr. florio
# no longer b lots of his <unk> <unk> campeau water used to redeem within N years it
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 61: train loss/word=3.7405, ppl=42.1202, time=147.62s
# iter 61: dev loss/word=5.4980, ppl=244.2045, time=4.49s
# most people have been in a <unk> staff
# revenue said
# canada corp. said it be made to acquisitions
# <unk> daily voters than <unk> the economic government may be a way for the year-ago period the N seconds ago but higher start-up costs are beginning to get words risk
# the poll last year from N yen up N cents
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 62: train loss/word=3.7297, ppl=41.6679, time=148.22s
# iter 62: dev loss/word=5.5028, ppl=245.3821, time=4.44s
# at least partly agreeing to run the company is worried about the plant was closed at $ N million level in mitsubishi estate a hand on professionals than london stocks during the N N
# it has reached for comment
# before the end crime was driven by the accounts units theater big new orders would rapidly be a combination of administration said congressional democrats want greece for intelligence and in coal prices if you are mad because they realize the <unk> system based in toronto stock exchange collateral
# one is a difficult sec ever breeden co. N million loss reserves equal legal growth
# prices in love for warner edward comment
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 63: train loss/word=3.7188, ppl=41.2166, time=145.74s
# iter 63: dev loss/word=5.5086, ppl=246.8045, time=4.45s
# because it 's good intentions and related <unk> the notion that a <unk> organization for example reported in the wake of its common shares via dillon read & co
# the smaller firm estimated that the educational term as president wrap s. <unk> should policies in central america
# the oil finished at N and they operate ships at improving the inaccurate
# see services be around beyond the company said revenue rose $ N million a year earlier its unfavorable as a rival
# mr. bush who visited the children also the treatment national patent on a new <unk>
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 64: train loss/word=3.7083, ppl=40.7852, time=143.85s
# iter 64: dev loss/word=5.5100, ppl=247.1620, time=4.45s
# often they want cause in may make interstate N of datapoint developing an hour test
# it was unable to prevent east germany
# banponce runs an <unk> <unk> & co. group and marketing everything they <unk> mr. <unk> 's drug-related
# such financial and a number of small-town associated with a net loss of the shares of the task of directors ' of improving since eastern 's creditors service fees N N N rate capped one-year adjustable rate mortgages
# indeed strategists say that matter
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 65: train loss/word=3.6980, ppl=40.3668, time=146.30s
# iter 65: dev loss/word=5.5184, ppl=249.2341, time=4.49s
# paramount measure of <unk> written by all else fails lost because the <unk> of raw material less boosted by race the president of attacks by moody 's opponents stressed that they got to obtain N years
# for example says john <unk> ltd. managing director of a chicago
# remember this is o. <unk> the rules merksamer chain he says that you 'd like the <unk> r.i. financial planner who <unk> much of space answers to questions the effect government now including three million people in the treasury bonds are insured and the company is that the comptroller back on output of business analysts have issues forecasts which connected notes
# the company said its acquisition of columbia pictures is an <unk> <unk> several times these rate indications are n't like many of whom directors to privacy of agip vessel involved in any investigation in malaysia
# eaton and topped which they get <unk> out red <unk> or companies and north america their affiliates arizona it hosts this market rallies decline in the state bank
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 66: train loss/word=3.6877, ppl=39.9538, time=147.27s
# iter 66: dev loss/word=5.5246, ppl=250.7951, time=4.42s
# we 're not supposed to change her because fear of a subsidiary company controls she is weeks
# it 's ted <unk> duties will exercise increase in gross domestic product with <unk>
# <unk> N days to establish a concrete this time to parity with costly promotions
# tribune said <unk> on a new offer to N N did n't expect a chemical spokeswoman said that amended dentsu has n't been served as vice president dan quayle who was <unk> off a government and <unk>
# they insist on wall street journal of <unk>
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 67: train loss/word=3.6780, ppl=39.5673, time=147.11s
# iter 67: dev loss/word=5.5261, ppl=251.1721, time=4.45s
# ad ventures judicial restraint <unk> not the end when the normal <unk>
# the troubles were being caused <unk> by the sources he said
# municipal data
# some investors think about the size of the government 's disagreement
# the minimum unit of ford chairman of the <unk> investors say buying mgm\/ua against installation of buying power lines far east
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 68: train loss/word=3.6684, ppl=39.1885, time=147.14s
# iter 68: dev loss/word=5.5291, ppl=251.9256, time=4.48s
# sunday uncertainty in the money managers are <unk> of rome excluding the huge national payment of new equipment have occurred among airlines
# john r. parker drilling co. junk bond market falls little income
# the guy associates who do n't have a pay cease-fire
# the most global offer
# the staggering stock market tremors too small started highly educated <unk> in greater market than anticipated levels of <unk> executives
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 69: train loss/word=3.6591, ppl=38.8272, time=145.45s
# iter 69: dev loss/word=5.5369, ppl=253.8903, time=4.43s
# japanese researchers are cut
# the company ai n't end up N N to N N of <unk> with violating ltd
# catastrophes are getting out fixed commissions under $ N million of the bikes
# in japan britain 's <unk> stock prices in the first phase of an atmospheric government national mortgage association archrival <unk> on sports afford to have stalled an operator democratic lbos could drop in the equity rose at $ N a share on revenue of $ N million contract revenue however about average close
# after the hospital tourist 's <unk> earthquake as of many software
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 70: train loss/word=3.6497, ppl=38.4617, time=145.78s
# iter 70: dev loss/word=5.5402, ppl=254.7331, time=4.43s
# john pope lone star steel corp. merksamer chain
# and <unk> swiftly and the risks equivalent to <unk> the journal science with nearly N N although afternoon gop is <unk>
# <unk> us it closed narrowly mixed in hong kong chase will have <unk>
# the year-ago period
# and investors <unk> 's wall street reflects <unk> on the board specialist 's <unk> a new securities and exchange where it was widely known as president and chief executive and apart
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 71: train loss/word=3.6406, ppl=38.1137, time=143.76s
# iter 71: dev loss/word=5.5442, ppl=255.7421, time=4.46s
# the military equipment said it extended to build a slim and N p.m. edt $ N a enforcers used <unk> pricing dig is the world series <unk> for a critical committee on the transactions
# volume and german television in this case the <unk> the libel brunt of joint ventures are being cold but they also suggests that although georgia gulf because there was a <unk> into a capital-gains amendment can abortion restrictions last week in her case holder to buy gold stocks closed lower
# weirton of the exchequer might be <unk>
# maybe the chinese customs and syndicate manager as compiled by dow jones capital markets after mr. freeman was an <unk> food aid had over several years at the gorbachev will stem mr. courter also declined to comment further
# <unk> robert <unk> of just three years
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 72: train loss/word=3.6317, ppl=37.7757, time=144.44s
# iter 72: dev loss/word=5.5478, ppl=256.6717, time=4.43s
# the pilot program to the news conference to assess future returns
# mission mr. russell
# though judge keenan threw out
# anheuser said it wo n't <unk> acceptable in an effort to finance who makes them hard disk it could n't convinced the political oil
# at a bad bank of japan that big three stocks that changed
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 73: train loss/word=3.6234, ppl=37.4635, time=145.94s
# iter 73: dev loss/word=5.5513, ppl=257.5664, time=4.45s
# great saatchi & saatchi said that <unk> director of this <unk> it would probably worth the time mr. guzman cabrera says one entity cent from sir james goldsmith d. <unk> in a brief european government is the line near an <unk> value of units of the netherlands
# just as confused <unk> of a subsidiary of itt said it expects to achieve a N to something democratic members
# all also plans an increase revival of a bankruptcy element in the way to air from moving <unk> 190-point emotional issue is talking about
# five million dollars in assets
# he says
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 74: train loss/word=3.6149, ppl=37.1485, time=141.96s
# iter 74: dev loss/word=5.5647, ppl=261.0432, time=4.35s
# but dataproducts are almost everyone in the coffee market said the texas banks investment in paris as $ N and a new york 's former world executive boosted his state brokers on boeing N through N that the parallel aspect of the direct desire for predicts officials hot investment what the ual buy-out other fare
# warner apartment
# the government plant and will exceed the record are of course
# he expects more to our agricultural now goes to character
# revenue bonds series typically is somehow <unk>
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 75: train loss/word=3.6063, ppl=36.8302, time=141.51s
# iter 75: dev loss/word=5.5595, ppl=259.6872, time=4.40s
# along the rest of rico prosecutions have been <unk>
# the average
# mr. stern was down N cents in composite trading
# whitbread five offers left with words east german shares held a conference range for about N reports of economic north central wyss
# the company 's australian and canadian nearly acceptance of replacement tires
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 76: train loss/word=3.5983, ppl=36.5346, time=144.98s
# iter 76: dev loss/word=5.5675, ppl=261.7724, time=4.52s
# one step anheuser said it 's two consumption by the ig metall labor union reported that produced as the <unk> step
# <unk> <unk> the project comes from the year-earlier third world that previously announced that it is one mundane the company said yesterday 's edition and was itself as a balanced s&p
# and bill can also bar <unk> and about a N N from central and the stock purchase one entity that is largely because of continued to represent charles bradford an analyst with macy and is usually to earthquakes small investors dumped on <unk> mission
# industry officials have to bottom it is too much much because mr. <unk> said he <unk>
# <unk> <unk> <unk> cable 's portfolio owner and retain their rights leader in <unk> <unk> iii accountants and <unk> he made desperate for the reception reflected before <unk> 's intent to distribute par via commerzbank banking and restaurants you have filed on behalf of mr. dinkins lost twice the average fell N N on a hedge or a contact with mr. <unk> saying that her two scenes from succeed in columbus ohio consulting firm
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
# --finished 30000 sentences
# --finished 35000 sentences
# --finished 40000 sentences
# iter 77: train loss/word=3.5906, ppl=36.2547, time=142.22s
# iter 77: dev loss/word=5.5685, ppl=262.0282, time=4.39s
# fiat 's <unk> that <unk>
# prices during the reagan revolution and make total $ N a share ton
# last year to $ N million from as much as N N N of a vessel meeting the filing
# the sec <unk> of the <unk> <unk> in east and other troubled valley national bank
# rated climbed N N while N nekoosa into negotiating mr. sinyard 's often have him recognition he helped to narrow <unk> as president powers has attracted to support it is n't clear whether the irs says thomas <unk> chairman <unk> N she homeowners
# --finished 5000 sentences
# --finished 10000 sentences
# --finished 15000 sentences
# --finished 20000 sentences
# --finished 25000 sentences
